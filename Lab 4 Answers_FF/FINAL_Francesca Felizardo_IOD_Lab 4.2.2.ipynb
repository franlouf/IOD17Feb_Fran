# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.2: Feature Selection

# %% [markdown]
# Moving beyond basic feature selection methods, this lab introduces forward feature selection. Through an iterative process, we progressively include features that contribute to improving the model's adjusted R-squared score. By systematically evaluating the impact of each feature, we aim to construct a regression model that captures the underlying patterns in the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

# Load the wine dataset from csv
wine = pd.read_csv('/Users/francescafelizardo/Documents/Francesca/IOD - UTS - Data Analytics and AI Program/Modules/DATA/winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
model = LinearRegression()
n = X_train.shape[0]

while True:
    changed = False

    if show_steps:
        print('')

    excluded = list(set(X.columns) - set(included))

    if show_steps:
        print(f"(Step) Excluded = {', '.join(excluded)}")

    for new_column in excluded:

        if show_steps:
            print(f"(Step) Trying {new_column}...")
            print(f"(Step) - Features = {', '.join(included + [new_column])}")

        # Select current set of features
        X_train_subset = X_train[included + [new_column]]

        # Fit the model
        model.fit(X_train_subset, y_train)
        y_pred = model.predict(X_train_subset)
        r2 = r2_score(y_train, y_pred)

        # Number of predictors
        k = len(included) + 1

        # Adjusted R^2 formula
        adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - k - 1)

        if show_steps:
            print(f"(Step) - Adjusted R^2: This = {adjusted_r2:.3f}; Best = {best['a_r2']:.3f}")

        # If this model improves adjusted R^2
        if adjusted_r2 > best['a_r2']:
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            changed = True
            if show_steps:
                print(f"(Step) - New Best!   : Feature = {best['feature']}; R^2 = {best['r2']:.3f}; Adjusted R^2 = {best['a_r2']:.3f}")

    # End for

    if changed:
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print(f"Added feature {best['feature']} with R^2 = {best['r2']:.3f} and adjusted R^2 = {best['a_r2']:.3f}")
    else:
        break

print('\nResulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = citric acid, total sulfur dioxide, density, red_wine, residual sugar, fixed acidity, sulphates, volatile acidity, free sulfur dioxide, alcohol, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.008; Best = 0.000
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.008; Adjusted R^2 = 0.008
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.001; Best = 0.008
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.096; Best = 0.008
# (Step) - New Best!   : Feature = density; R^2 = 0.096; Adjusted R^2 = 0.096
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.014; Best = 0.096
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = 0.001; Best = 0.096
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.006; Best = 0.096
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = 0.001; Best = 0.096
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.068; Best = 0.096
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.002; Best = 0.096
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.202; Best = 0.096
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.202; Adjusted R^2 = 0.202
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.038; Best = 0.202
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = -0.000; Best = 0.202
# Added feature alcohol with R^2 = 0.202 and adjusted R^2 = 0.202
#
# (Step) Excluded = citric acid, total sulfur dioxide, density, red_wine, residual sugar, fixed acidity, sulphates, volatile acidity, free sulfur dioxide, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.210; Best = 0.202
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.211; Adjusted R^2 = 0.210
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.209; Best = 0.210
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.202; Best = 0.210
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.213; Best = 0.210
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.213; Adjusted R^2 = 0.213
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.220; Best = 0.213
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.220; Adjusted R^2 = 0.220
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.203; Best = 0.220
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.203; Best = 0.220
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.262; Best = 0.220
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.263; Adjusted R^2 = 0.262
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.220; Best = 0.262
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.208; Best = 0.262
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.204; Best = 0.262
# Added feature volatile acidity with R^2 = 0.263 and adjusted R^2 = 0.262
#
# (Step) Excluded = citric acid, total sulfur dioxide, density, red_wine, residual sugar, fixed acidity, sulphates, free sulfur dioxide, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.262; Best = 0.262
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.263; Best = 0.262
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.264; Adjusted R^2 = 0.263
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.270; Best = 0.263
# (Step) - New Best!   : Feature = density; R^2 = 0.270; Adjusted R^2 = 0.270
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.268; Best = 0.270
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.269; Best = 0.270
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.263; Best = 0.270
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.272; Best = 0.270
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.273; Adjusted R^2 = 0.272
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.265; Best = 0.272
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.263; Best = 0.272
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.263; Best = 0.272
# Added feature sulphates with R^2 = 0.273 and adjusted R^2 = 0.272
#
# (Step) Excluded = citric acid, total sulfur dioxide, density, red_wine, residual sugar, fixed acidity, free sulfur dioxide, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.273; Best = 0.272
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.273; Adjusted R^2 = 0.273
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.272; Best = 0.273
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, density
# (Step) - Adjusted R^2: This = 0.276; Best = 0.273
# (Step) - New Best!   : Feature = density; R^2 = 0.276; Adjusted R^2 = 0.276
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, red_wine
# (Step) - Adjusted R^2: This = 0.273; Best = 0.276
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar
# (Step) - Adjusted R^2: This = 0.282; Best = 0.276
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.282; Adjusted R^2 = 0.282
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.272; Best = 0.282
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.276; Best = 0.282
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.273; Best = 0.282
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, pH
# (Step) - Adjusted R^2: This = 0.272; Best = 0.282
# Added feature residual sugar with R^2 = 0.282 and adjusted R^2 = 0.282
#
# (Step) Excluded = citric acid, total sulfur dioxide, density, red_wine, fixed acidity, free sulfur dioxide, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.282; Best = 0.282
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.283; Adjusted R^2 = 0.282
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.284; Best = 0.282
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.285; Adjusted R^2 = 0.284
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, density
# (Step) - Adjusted R^2: This = 0.282; Best = 0.284
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.285; Best = 0.284
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.286; Adjusted R^2 = 0.285
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.281; Best = 0.285
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.283; Best = 0.285
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.282; Best = 0.285
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.282; Best = 0.285
# Added feature red_wine with R^2 = 0.286 and adjusted R^2 = 0.285
#
# (Step) Excluded = citric acid, total sulfur dioxide, density, fixed acidity, free sulfur dioxide, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.286; Best = 0.285
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.287; Adjusted R^2 = 0.286
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.285; Best = 0.286
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.290; Best = 0.286
# (Step) - New Best!   : Feature = density; R^2 = 0.291; Adjusted R^2 = 0.290
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.286; Best = 0.290
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.288; Best = 0.290
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.286; Best = 0.290
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.286; Best = 0.290
# Added feature density with R^2 = 0.291 and adjusted R^2 = 0.290
#
# (Step) Excluded = citric acid, total sulfur dioxide, fixed acidity, free sulfur dioxide, chlorides, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, citric acid
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.291; Adjusted R^2 = 0.290
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.292; Best = 0.290
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.293; Adjusted R^2 = 0.292
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides
# (Step) - Adjusted R^2: This = 0.290; Best = 0.292
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, pH
# (Step) - Adjusted R^2: This = 0.291; Best = 0.292
# Added feature free sulfur dioxide with R^2 = 0.293 and adjusted R^2 = 0.292
#
# (Step) Excluded = citric acid, total sulfur dioxide, fixed acidity, pH, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.292; Best = 0.292
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.294; Best = 0.292
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.295; Adjusted R^2 = 0.294
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.292; Best = 0.294
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.292; Best = 0.294
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.292; Best = 0.294
# Added feature total sulfur dioxide with R^2 = 0.295 and adjusted R^2 = 0.294
#
# (Step) Excluded = fixed acidity, citric acid, chlorides, pH
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.295; Adjusted R^2 = 0.294
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.293; Best = 0.294
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.295; Adjusted R^2 = 0.294
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# Added feature chlorides with R^2 = 0.295 and adjusted R^2 = 0.294
#
# (Step) Excluded = fixed acidity, citric acid, pH
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, fixed acidity
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.296; Adjusted R^2 = 0.294
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, citric acid
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, pH
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# Added feature fixed acidity with R^2 = 0.296 and adjusted R^2 = 0.294
#
# (Step) Excluded = pH, citric acid
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, fixed acidity, pH
# (Step) - Adjusted R^2: This = 0.297; Best = 0.294
# (Step) - New Best!   : Feature = pH; R^2 = 0.299; Adjusted R^2 = 0.297
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.295; Best = 0.297
# Added feature pH with R^2 = 0.299 and adjusted R^2 = 0.297
#
# (Step) Excluded = citric acid
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, fixed acidity, pH, citric acid
# (Step) - Adjusted R^2: This = 0.297; Best = 0.297
#
# Resulting features:
# alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide, total sulfur dioxide, chlorides, fixed acidity, pH

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
